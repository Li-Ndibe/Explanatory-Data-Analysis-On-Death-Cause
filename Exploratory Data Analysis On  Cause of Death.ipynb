# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# shows plots in jupyter notebook
# %matplotlib inline

#set plot style
sns.set(color_codes=True)

# %%
# to load dataset with Pandas
cd = pd.read_csv('C:/Users/LILIAN/Desktop/Exploratory Data Analysis/cause_of_deaths.csv')

# %%
#View the data
cd.head()
# Out:
#        Country Code  Year  Meningitis  Dementias  Parkinson_Disease  \
# 0  Afghanistan  AFG  1990        2159       1116                371
# 1  Afghanistan  AFG  1991        2218       1136                374
# 2  Afghanistan  AFG  1992        2475       1162                378
# 3  Afghanistan  AFG  1993        2812       1187                384
# 4  Afghanistan  AFG  1994        3027       1211                391
#
#    Nutritional_Deficiencies  Malaria  Drowning  Interpersonal_Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# 3                      2837      108      1687                    2589  ...
# 4                      3081      211      1809                    2849  ...
#
#    Diabetes_Mellitus  Kidney_Disease  Poisonings  Protein_Malnutrition  \
# ...

# %%
#replace space in columns 
cd.columns = cd.columns.str.replace(' ','')

# %%
#convert year to the right datatype
#cd["Year"] = pd.to_datetime(cd["Year"])

# %%
# Checking the statistical summary of the numerical variables in the dataset 
# 'T' is to transpose the output
cd.describe().T
# Out:
#                               count          mean            std     min  \
# Year                         6120.0   2004.500000       8.656149  1990.0
# Meningitis                   6120.0   1719.701307    6672.006930     0.0
# Dementias                    6120.0   4864.189379   18220.659072     0.0
# Parkinson_Disease            6120.0   1173.169118    4616.156238     0.0
# Nutritional_Deficiencies     6120.0   2253.600000   10483.633601     0.0
# Malaria                      6120.0   4140.960131   18427.753137     0.0
# Drowning                     6120.0   1683.333170    8877.018366     0.0
# Interpersonal_Violence       6120.0   2083.797222    6917.006075     0.0
# Maternal_Disorders           6120.0   1262.589216    6057.973183     0.0
# HIV_AIDS                     6120.0   5941.898529   21011.962487     0.0
# Drug_Use_Disorders           6120.0    434.006699    2898.761628     0.0
# Tuberculosis                 6120.0   7491.928595   39549.977578     0.0
# ...

# %%
# Checking the summary of non-numerical values in the dataset

cd.describe(exclude = 'number').T
# Out:
#         count unique                           top freq
# Country  6120    204  Democratic Republic of Congo   30
# Code     6120    204                           ARG   30

# %%
#drop duplicate rows- if any
cd = cd.drop_duplicates(keep='first')

# %%
# Total Number Countries
cd.Country.nunique()
len(cd.Country.unique())
# Out:
# 204

# %%
# Basic information and description

cd.info()

cd.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      6120 non-null   object
#  1   Code                         6120 non-null   object
#  2   Year                         6120 non-null   int64
#  3   Meningitis                   6120 non-null   int64
#  4   Dementias                    6120 non-null   int64
#  5   Parkinson_Disease            6120 non-null   int64
#  6   Nutritional_Deficiencies     6120 non-null   int64
#  7   Malaria                      6120 non-null   int64
#  8   Drowning                     6120 non-null   int64
#  9   Interpersonal_Violence       6120 non-null   int64
#  10  Maternal_Disorders           6120 non-null   int64
#  11  HIV_AIDS                     6120 non-null   int64
#  12  Drug_Use_Disorders           6120 non-null   int64
# ...

# %% [raw]
# There are no missing values in the dataset
# There are 30 'int64' and 2 'objects' and 1 'datetime64'columns
# Memory space utilisied by the data file is 1.6+ MB
# THERE ARE 6120 ROWS AND 34 VARIABLES

# %%
#checking for Missing Values :

cd.isna().sum()
# Out:
# Country                        0
# Code                           0
# Year                           0
# Meningitis                     0
# Dementias                      0
# Parkinson_Disease              0
# Nutritional_Deficiencies       0
# Malaria                        0
# Drowning                       0
# Interpersonal_Violence         0
# Maternal_Disorders             0
# HIV_AIDS                       0
# Drug_Use_Disorders             0
# Tuberculosis                   0
# Cardiovascular_Diseases        0
# Lower_RespiratoryInfections    0
# Neonatal_Disorders             0
# Alcohol_Disorders              0
# Self_harm                      0
# Nature_Forces                  0
# Diarrheal_Diseases             0
# Environmental_Exposure         0
# Neoplasms                      0
# Conflict                       0
# Diabetes_Mellitus              0
# Kidney_Disease                 0
# Poisonings                     0
# Protein_Malnutrition           0
# ...

# %%
cd.Year.unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
# Grouping the data based on the year

year = cd.groupby([cd.Year])

# %%
# Checking the number of observations available for each year

year.size()
# Out:
# Year
# 1990    204
# 1991    204
# 1992    204
# 1993    204
# 1994    204
# 1995    204
# 1996    204
# 1997    204
# 1998    204
# 1999    204
# 2000    204
# 2001    204
# 2002    204
# 2003    204
# 2004    204
# 2005    204
# 2006    204
# 2007    204
# 2008    204
# 2009    204
# 2010    204
# 2011    204
# 2012    204
# 2013    204
# 2014    204
# 2015    204
# 2016    204
# 2017    204
# 2018    204
# 2019    204
# dtype: int64

# %% [raw]
# Each year contains 204 observations

# %% [markdown]
# # Individually analysing the numerical values based on the year.

# %%
# Looking for the minimum value

year.min()
# Out:
#           Country Code  Meningitis  Dementias  Parkinson_Disease  \
# Year
# 1990  Afghanistan  AFG           0          0                  0
# 1991  Afghanistan  AFG           0          0                  0
# 1992  Afghanistan  AFG           0          0                  0
# 1993  Afghanistan  AFG           0          0                  0
# 1994  Afghanistan  AFG           0          0                  0
# 1995  Afghanistan  AFG           0          0                  0
# 1996  Afghanistan  AFG           0          0                  0
# 1997  Afghanistan  AFG           0          0                  0
# 1998  Afghanistan  AFG           0          0                  0
# 1999  Afghanistan  AFG           0          0                  0
# 2000  Afghanistan  AFG           0          0                  0
# 2001  Afghanistan  AFG           0          0                  0
# 2002  Afghanistan  AFG           0          0                  0
# ...

# %% [raw]
# IN ALL THE YEARS,AFGHANISTAN HAS THE MINIMUM VALUE OF O FOR ALL FEATURES EXCEPT FOR Kidney_Disease,Digestive_Diseases,Respiratory_Diseases WHERE THER IS A MIX OF O, 1 ANF 2

# %%
# Looking for the maximum value

year.max()
# Out:
#        Country Code  Meningitis  Dementias  Parkinson_Disease  \
# Year
# 1990  Zimbabwe  ZWE       98358      93316              31920
# 1991  Zimbabwe  ZWE       97134      95470              32607
# 1992  Zimbabwe  ZWE       94891      98135              33287
# 1993  Zimbabwe  ZWE       91783     100822              34129
# 1994  Zimbabwe  ZWE       88221     103621              34680
# 1995  Zimbabwe  ZWE       86142     106958              35450
# 1996  Zimbabwe  ZWE       83642     111481              36703
# 1997  Zimbabwe  ZWE       82891     116489              37807
# 1998  Zimbabwe  ZWE       80366     121766              38955
# 1999  Zimbabwe  ZWE       78524     127660              40894
# 2000  Zimbabwe  ZWE       77606     134438              43357
# 2001  Zimbabwe  ZWE       75064     141288              45240
# 2002  Zimbabwe  ZWE       71130     148675              47020
# 2003  Zimbabwe  ZWE       67440     156132              48660
# ...

# %% [raw]
# ZIMBABWE RECORDED THE MAXIMUN NUMBERS IN ALL VARIABELES

# %%
# Looking for the mean of the values 

year.mean()
# Out:
#        Meningitis    Dementias  Parkinson_Disease  Nutritional_Deficiencies  \
# Year
# 1990  2118.887255  2748.117647         721.352941               3709.843137
# 1991  2101.083333  2858.656863         739.583333               3574.240196
# 1992  2090.392157  2970.068627         759.245098               3434.627451
# 1993  2062.921569  3086.132353         785.534314               3304.995098
# 1994  2028.426471  3196.941176         805.789216               3185.299020
# 1995  2008.950980  3307.916667         827.852941               3544.583333
# 1996  2045.387255  3415.024510         852.068627               3294.004902
# 1997  1965.161765  3516.382353         879.151961               3174.911765
# 1998  1928.254902  3621.411765         907.338235               3041.656863
# 1999  1912.431373  3733.431373         938.911765               2908.906863
# 2000  1892.127451  3855.955882         973.259804               2786.539216
# ...

# %% [raw]
# In year 2019 'Respiratory_Diseases' has the highest average values of 19473.926471 while death by poisining recorded the lowest average of 378.088235.

# %%
# Looking for the standard deviations for each category

year.std()
# Out:
#        Meningitis     Dementias  Parkinson_Disease  Nutritional_Deficiencies  \
# Year
# 1990  8406.655144   9268.089195        2703.407620              19894.484048
# 1991  8344.199573   9654.925123        2769.261832              18811.861837
# 1992  8219.665539  10046.806829        2832.188478              17653.519852
# 1993  8046.276325  10453.748342        2918.944879              16583.584492
# 1994  7850.338158  10828.991607        2978.899623              15621.982391
# 1995  7732.795452  11213.848014        3049.998052              16148.614179
# 1996  7948.068464  11588.619218        3158.671495              14569.450855
# 1997  7495.155267  11927.006944        3277.876485              13758.309378
# 1998  7362.169212  12280.300038        3390.802115              12797.077764
# 1999  7249.842855  12684.275164        3535.765690              11830.492297
# 2000  7211.170676  13172.752914        3723.438410              11067.518254
# ...

# %% [markdown]
# # Analysing the relationships between numerical variables

# %%
# finding the correlation between values and assigning the same to the variable data_correlation

cd.corr().style.background_gradient(cmap ='coolwarm')
# Out:
# <style  type="text/css" >
# #T_7107a_row0_col0,#T_7107a_row1_col1,#T_7107a_row2_col2,#T_7107a_row3_col3,#T_7107a_row4_col4,#T_7107a_row5_col5,#T_7107a_row6_col6,#T_7107a_row7_col7,#T_7107a_row8_col8,#T_7107a_row9_col9,#T_7107a_row10_col10,#T_7107a_row11_col11,#T_7107a_row12_col12,#T_7107a_row13_col13,#T_7107a_row14_col14,#T_7107a_row15_col15,#T_7107a_row16_col16,#T_7107a_row17_col17,#T_7107a_row18_col18,#T_7107a_row19_col19,#T_7107a_row20_col20,#T_7107a_row21_col21,#T_7107a_row22_col22,#T_7107a_row23_col23,#T_7107a_row24_col24,#T_7107a_row25_col25,#T_7107a_row26_col26,#T_7107a_row27_col27,#T_7107a_row28_col28,#T_7107a_row29_col29,#T_7107a_row30_col30,#T_7107a_row31_col31{
#             background-color:  #b40426;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# # HEATMAP

# %%
plt.figure(figsize=(15,15))
sns.heatmap(cd.corr(),annot=True,linewidths = 0.8,linecolor = 'white')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Positive correlations spotted between the following:
#
# All BOXES RECOREDED GREATER THAN 0.6 HAVE VERY STRONG CORRELATION.
# ALL  BOXES RECOREDED 0.6 BELOW HAVE STRONG POSITIVE CORRELATION

# %% [markdown]
# # PAIRPLOT

# %%
#correlation plots using 'pairplot'
for i in range(0, len(cd.columns),10):
    sns.pairplot(cd, y_vars=['Country'],x_vars=cd.columns[i:i+10])

# %% [markdown]
# # CONDITIONAL SELECTION

# %%
#select only data from year 1990

cd.loc[cd['Year'] == 1990]
# Out:
#              Country Code  Year  Meningitis  Dementias  Parkinson_Disease  \
# 0        Afghanistan  AFG  1990        2159       1116                371
# 30           Albania  ALB  1990         107        360                 93
# 60           Algeria  DZA  1990         838       1337                439
# 90    American Samoa  ASM  1990           1          3                  1
# 120          Andorra  AND  1990           0          6                  2
# ...              ...  ...   ...         ...        ...                ...
# 5970       Venezuela  VEN  1990         666       1629                282
# 6007         Vietnam  VNM  1990        2049       7765               1633
# 6039           Yemen  YEM  1990         911        528                119
# 6060          Zambia  ZMB  1990        4562        284                 88
# 6090        Zimbabwe  ZWE  1990        1132        457                123
#
#       Nutritional_Deficiencies  Malaria  Drowning  Interpersonal_Violence  \
# ...

# %%
#Select only the rows where the country is Nigeria or United States
cd.loc[cd['Country'].isin(['Nigeria', 'United States'])]
# Out:
#             Country Code  Year  Meningitis  Dementias  Parkinson_Disease  \
# 3870        Nigeria  NGA  2007       57314       8602               2342
# 3871        Nigeria  NGA  2008       56276       8938               2447
# 3872        Nigeria  NGA  2009       59349       9213               2533
# 3873        Nigeria  NGA  2013       52141      10472               2917
# 3874        Nigeria  NGA  2016       49572      11041               3053
# 3875        Nigeria  NGA  1990       40226       4984               1431
# 3876        Nigeria  NGA  1991       41349       5107               1460
# 3877        Nigeria  NGA  1992       42711       5255               1496
# 3878        Nigeria  NGA  1993       44166       5395               1528
# 3879        Nigeria  NGA  1994       45460       5540               1557
# 3880        Nigeria  NGA  1995       46492       5654               1578
# 3881        Nigeria  NGA  1996       59006       5754               1592
# ...

# %%
#getting the total meningitis cause of death for each year in countries 
Meningitis_cd = cd.groupby(['Year','Country']).Meningitis.agg([max])
Meningitis_cd
# Out:
#                       max
# Year Country
# 1990 Afghanistan     2159
#      Albania          107
#      Algeria          838
#      American Samoa     1
#      Andorra            0
# ...                   ...
# 2019 Venezuela        254
#      Vietnam          747
#      Yemen            479
#      Zambia          2065
#      Zimbabwe        1450
#
# [6120 rows x 1 columns]

# %%
cd.columns
# Out:
# Index(['Country', 'Code', 'Year', 'Meningitis', 'Dementias',
#        'Parkinson_Disease', 'Nutritional_Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal_Violence', 'Maternal_Disorders', 'HIV_AIDS',
#        'Drug_Use_Disorders', 'Tuberculosis', 'Cardiovascular_Diseases',
#        'Lower_RespiratoryInfections', 'Neonatal_Disorders',
#        'Alcohol_Disorders', 'Self_harm', 'Nature_Forces', 'Diarrheal_Diseases',
#        'Environmental_Exposure', 'Neoplasms', 'Conflict', 'Diabetes_Mellitus',
#        'Kidney_Disease', 'Poisonings', 'Protein_Malnutrition', 'Road_Injuries',
#        'Respiratory_Diseases', 'Liver_Diseases', 'Digestive_Diseases',
#        'Hot_Substances', 'Acute_Hepatitis'],
#       dtype='object')

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# CONCATENATE SOME VARIABELS

# %%
death_cause = ['Meningitis', 'Dementias',
       'Parkinson_Disease', 'Nutritional_Deficiencies', 'Malaria', 'Drowning',
       'Interpersonal_Violence', 'Maternal_Disorders', 'HIV_AIDS',
       'Drug_Use_Disorders', 'Tuberculosis', 'Cardiovascular_Diseases',
       'Lower_RespiratoryInfections', 'Neonatal_Disorders',
       'Alcohol_Disorders', 'Self_harm', 'Nature_Forces', 'Diarrheal_Diseases',
       'Environmental_Exposure', 'Neoplasms', 'Conflict', 'Diabetes_Mellitus',
       'Kidney_Disease', 'Poisonings', 'Protein_Malnutrition', 'Road_Injuries',
       'Respiratory_Diseases', 'Liver_Diseases', 'Digestive_Diseases',
       'Hot_Substances', 'Acute_Hepatitis']

# %%
# Creating a new column for 'death_sum' for individual Country and Year

cd['death_sum'] = cd[death_cause].sum(axis=1)

# %%
# Top 10 Deaths sum

top10_death_sum = cd.sort_values(by='death_sum',ascending=False)[:10][['death_sum','Country']]

top10_death_sum
# Out:
#       death_sum Country
# 1139   10442561   China
# 1138   10163943   China
# 1137    9978653   China
# 1119    9814213   China
# 1118    9591222   China
# 1117    9503904   China
# 1116    9411928   China
# 1114    9366974   China
# 1115    9364587   China
# 1113    9284664   China

# %% [markdown]
# CHINA RECORDED THE HIGHEST TOTAL DEATH ALL YEAR. IT MAY BE DUE TO HER POPULATION SIZE

# %%
#select on Nigeria
cd[cd.Country == "China"]
# Out:
#      Country Code  Year  Meningitis  Dementias  Parkinson_Disease  \
# 1110   China  CHN  2007        8407     187358              52766
# 1111   China  CHN  2008        8384     197380              54828
# 1112   China  CHN  2009        8394     208139              57485
# 1113   China  CHN  2010        8341     218436              60241
# 1114   China  CHN  2011        8193     225852              61781
# 1115   China  CHN  2012        8057     232656              62640
# 1116   China  CHN  2013        7971     239240              63853
# 1117   China  CHN  2014        7740     249056              65555
# 1118   China  CHN  2015        7553     259217              66761
# 1119   China  CHN  2016        7550     275481              69364
# 1120   China  CHN  1990       37473      93316              31920
# 1121   China  CHN  1991       36834      95470              32607
# 1122   China  CHN  1992       35086      98135              33287
# ...

# %%
#YEARLY DEATH SUM IN CHINA

China_death_sum = cd[cd['Country']=='China'].sort_values(by='death_sum',ascending=False)

# %%
#PLOTTING THE YEARLY DEATH SUM IN CHINA

plt.figure(figsize=(8,4),dpi=80)
sns.scatterplot(data=China_death_sum, x='Year', y='death_sum')
plt.xlabel("Year")
plt.ylabel("death_sum")
plt.title("Yearly Total Number of Death in China")
plt.show()

# %% [markdown]
# THE ABOVE PLOT SHOWS THERE IS ACONSISTENT RISE IN THE YEARLY TOTAL DEATH RECORDED ON CHINA, THOUGH THERE WAS A REDUCTION IN 2006 AND 2007.

# %% [markdown]
# # ANALYSIS OF DEATH CAUSES IN NIGERIA

# %%
#select on Nigeria
cd[cd.Country == "Nigeria"]
# Out:
#       Country Code  Year  Meningitis  Dementias  Parkinson_Disease  \
# 3870  Nigeria  NGA  2007       57314       8602               2342
# 3871  Nigeria  NGA  2008       56276       8938               2447
# 3872  Nigeria  NGA  2009       59349       9213               2533
# 3873  Nigeria  NGA  2013       52141      10472               2917
# 3874  Nigeria  NGA  2016       49572      11041               3053
# 3875  Nigeria  NGA  1990       40226       4984               1431
# 3876  Nigeria  NGA  1991       41349       5107               1460
# 3877  Nigeria  NGA  1992       42711       5255               1496
# 3878  Nigeria  NGA  1993       44166       5395               1528
# 3879  Nigeria  NGA  1994       45460       5540               1557
# 3880  Nigeria  NGA  1995       46492       5654               1578
# 3881  Nigeria  NGA  1996       59006       5754               1592
# 3882  Nigeria  NGA  1997       48278       5894               1614
# ...

# %%
# YEARLY DEATH CAUSES IN NIGERIA

Naija_death_sum = cd[cd['Country']=='Nigeria'].sort_values(by='death_sum',ascending=False)

# %%
#PLOTTING THE YEARLY DEATH SUM IN NIGERIA

plt.figure(figsize=(8,4),dpi=80)
sns.scatterplot(data=Naija_death_sum, x='Year', y='death_sum')
plt.xlabel("Year")
plt.ylabel("death_sum")
plt.title("Yearly Total Number of Death in NIGERIA")
plt.show()

# %% [markdown]
# THE SCATTER PLOT SHOWS A CONSISTENT RISE IN THE YEARLY TOTAL DEATH UNTILL 2005, THE A MAGICAL DROP UNTILL 2019. IT LOOKS LIKE NIGERIA FOUND A SOLUTION TO HER DEATH RATE

# %%
#BAR PLOT OF SAME DATA

plt.figure(figsize=(15,8),dpi=60)
sns.barplot(data=Naija_death_sum, x='Year', y='death_sum')
plt.xlabel("Year")
plt.ylabel("death_sum")
plt.title("Yearly Total Number of Death in NIGERIA")
plt.show()

# %% [markdown]
# # COMMON CAUSES OF DEATH IN NIGERIA

# %%
#MALARIA DEATH

plt.figure(figsize=(12,8),dpi=60)
Naija_cd = Naija_death_sum.groupby(['Country','Year']).sum()
Naija_cd['Malaria'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Malaria Deaths")
plt.title("Yearly Malaria Death in Nigeria ")
plt.show()

# %% [markdown]
# 2008 SCORED THE HIGHEST MALARIA DEATH IN NIGERIA AND THERE IS A GREAT REDUCTION IN 2017

# %%
#NATURE FORCES DEATH

plt.figure(figsize=(12,8),dpi=60)
Naija_cd = Naija_death_sum.groupby(['Country','Year']).sum()
Naija_cd['Nature_Forces'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Nature_Forces Deaths")
plt.title("Yearly Nature_Forces Death in Nigeria ")
plt.show()

# %% [markdown]
# NIGERIA RECORDED HIGHEST DEATH FROM NATURE FORCES IN 2012 AND 2018.

# %%
#ROAD INJURIES DEATH

plt.figure(figsize=(12,8),dpi=60)
Naija_cd = Naija_death_sum.groupby(['Country','Year']).sum()
Naija_cd['Road_Injuries'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Road_Injuries Deaths")
plt.title("Yearly Road_Injuries Death in Nigeria ")
plt.show()

# %% [markdown]
# SINCE 1990, RECORD OF DEATH BY ROAD ACCIDENTS IN NIGERIA HAVE BEEN ON THE RISE TILL 2017, 2018 & 2019 RECORDED A LITTLE DROP

# %%
#HIV_AIDS DEATH

plt.figure(figsize=(12,8),dpi=60)
Naija_cd = Naija_death_sum.groupby(['Country','Year']).sum()
Naija_cd['HIV_AIDS'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("HIV_AIDS Deaths")
plt.title("Yearly HIV_AIDS Death in Nigeria ")
plt.show()

# %% [markdown]
# HIV_AIDS DEATH CAUSE ROSE TILL 2004,DROPPED TILL 2014 AND STARTED RISING UNTIL 2019

# %% [markdown]
# # ANALYZING DEATH CAUSE IN UNITED STATES

# %%
# YEARLY DEATH CAUSES IN NIGERIA

USA_death_sum = cd[cd['Country']=='United States'].sort_values(by='death_sum',ascending=False)

# %%
#PLOTTING THE YEARLY DEATH SUM IN NIGERIA

plt.figure(figsize=(8,4),dpi=60)
sns.scatterplot(data=USA_death_sum, x='Year', y='death_sum')
plt.xlabel("Year")
plt.ylabel("death_sum")
plt.title("Yearly Total Number of Death in USA")
plt.show()

# %%
#BAR PLOT OF SAME DATA

plt.figure(figsize=(15,8),dpi=60)
sns.barplot(data=USA_death_sum, x='Year', y='death_sum')
plt.xlabel("Year")
plt.ylabel("death_sum")
plt.title("Yearly Total Number of Death in USA")
plt.show()

# %%
#MALARIA DEATH

plt.figure(figsize=(12,8),dpi=40)
USA_cd = USA_death_sum.groupby(['Country','Year']).sum()
USA_cd['Malaria'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Malaria Deaths")
plt.title("Yearly Malaria Death in USA")
plt.show()

# %% [markdown]
# THERE IS NO RECORD OF DEATH AS A  RESULT OF MALARIA IN USA, MEANING USA DO NOT EXPERIENCE MALARIA WHICH MAY BE AS RESULT OF HER WHEATHER

# %%
#NATURE FORCES DEATH

plt.figure(figsize=(12,8),dpi=60)
USA_cd = USA_death_sum.groupby(['Country','Year']).sum()
USA_cd['Nature_Forces'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Nature_Forces Deaths")
plt.title("Yearly Nature_Forces Death in USA")
plt.show()

# %%
#ROAD INJURIES DEATH

plt.figure(figsize=(12,8),dpi=60)
USA_cd = USA_death_sum.groupby(['Country','Year']).sum()
USA_cd['Road_Injuries'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Road_Injuries Deaths")
plt.title("Yearly Road_Injuries Death in USA")
plt.show()

# %%
#HIV_AIDS DEATH

plt.figure(figsize=(12,8),dpi=60)
USA_cd = USA_death_sum.groupby(['Country','Year']).sum()
USA_cd['HIV_AIDS'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("HIV_AIDS Deaths")
plt.title("Yearly HIV_AIDS Death in USA")
plt.show()

# %% [markdown]
# # COMPARING NIGERIA VS USA DEATH RECORDS

# %%
#Select only the rows where the country is Nigeria or United States
cd.loc[cd['Country'].isin(['Nigeria', 'United States'])]
# Out:
#             Country Code  Year  Meningitis  Dementias  Parkinson_Disease  \
# 3870        Nigeria  NGA  2007       57314       8602               2342
# 3871        Nigeria  NGA  2008       56276       8938               2447
# 3872        Nigeria  NGA  2009       59349       9213               2533
# 3873        Nigeria  NGA  2013       52141      10472               2917
# 3874        Nigeria  NGA  2016       49572      11041               3053
# 3875        Nigeria  NGA  1990       40226       4984               1431
# 3876        Nigeria  NGA  1991       41349       5107               1460
# 3877        Nigeria  NGA  1992       42711       5255               1496
# 3878        Nigeria  NGA  1993       44166       5395               1528
# 3879        Nigeria  NGA  1994       45460       5540               1557
# 3880        Nigeria  NGA  1995       46492       5654               1578
# 3881        Nigeria  NGA  1996       59006       5754               1592
# ...

# %% [markdown]
# # NATURE FORCES COMPARISON ON NIGERIA AND USA

# %%
#NATURE FORCES COMPARISON

#NATURE FORCES DEATH

plt.figure(figsize=(8,4),dpi=80)
USA_cd = USA_death_sum.groupby(['Country','Year']).sum()
USA_cd['Nature_Forces'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Nature_Forces Deaths")
plt.title("Yearly Nature_Forces Death in USA")

plt.figure(figsize=(8,4),dpi=80)
Naija_cd = Naija_death_sum.groupby(['Country','Year']).sum()
Naija_cd['Nature_Forces'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Nature_Forces Deaths")
plt.title("Yearly Nature_Forces Death in Nigeria ")
plt.show()

# %% [markdown]
# IN 2005, USA RECORDED HIGH DEATH RATE RESULTING FROM NATURE FORCES. WHILE IN 2012, NIGERIA RECORDED HIGH DEATH RESULTING FROM NATURE CAUSES

# %% [markdown]
# # COMPARING HIV DEATH RECORDS IN NIGERIA AND USA

# %%
#HIV_AIDS DEATH

plt.figure(figsize=(12,8),dpi=60)
Naija_cd = Naija_death_sum.groupby(['Country','Year']).sum()
Naija_cd['HIV_AIDS'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("HIV_AIDS Deaths")
plt.title("Yearly HIV_AIDS Death in Nigeria ")

plt.figure(figsize=(12,8),dpi=60)
USA_cd = USA_death_sum.groupby(['Country','Year']).sum()
USA_cd['HIV_AIDS'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("HIV_AIDS Deaths")
plt.title("Yearly HIV_AIDS Death in USA")
plt.show()

# %% [markdown]
# THERE ARE HIGH RECORD OF HIV DEATH IN THE USA EARLY 90s UNLIKE IN NIGERIA WHERE THE RECORD WAS LOW IN THE EARLY 90s. WHILE THE DEATH RECIRDS REDUCES  1997 IN THE USA,NIGERIA HAD MASSIVE INCREMENT ON THE HIV DEATH RECORD FROM 1997

# %%
# Total causes of death across 30 years

Total_cd= cd.groupby('Country').sum()
Total_cd.drop('Year',axis=1,inplace=True)

# %%
# Least 3 countries with death reords- For All the Years

Total_cd.sort_values(by='death_sum',ascending =True)[:3]
# Out:
#          Meningitis  Dementias  Parkinson_Disease  Nutritional_Deficiencies  \
# Country
# Tokelau           0          0                  0                         0
# Niue              0         12                  0                         0
# Nauru            19          0                  0                        22
#
#          Malaria  Drowning  Interpersonal_Violence  Maternal_Disorders  \
# Country
# Tokelau        0         0                       0                   0
# Niue           0         0                       0                   0
# Nauru          0        56                      30                  23
#
#          HIV_AIDS  Drug_Use_Disorders  ...  Kidney_Disease  Poisonings  \
# Country                                ...
# Tokelau         0                   0  ...               6           0
# Niue            0                   0  ...              30           0
# Nauru           6                   0  ...              81           0
#
# ...

# %%
# Top 3 countries with death reords- For All the Years

Total_cd.sort_values(by='death_sum',ascending =False)[:3]
# Out:
#                Meningitis  Dementias  Parkinson_Disease  \
# Country
# China              480899    5381846            1533092
# India             2008944    1707561             756832
# United States       40032    3302609             661288
#
#                Nutritional_Deficiencies  Malaria  Drowning  \
# Country
# China                            584236    13418   2873619
# India                           3290569  2439244   2110438
# United States                    133044        0    114752
#
#                Interpersonal_Violence  Maternal_Disorders  HIV_AIDS  \
# Country
# China                          776275              243257    433709
# India                         1237163             2292449   2454374
# United States                  596818               25206    528417
#
#                Drug_Use_Disorders  ...  Kidney_Disease  Poisonings  \
# Country                            ...
# China                      626914  ...         4195276      770140
# ...

# %% [markdown]
# FROM THE TABLE ABOVE, TOKELAU, NIUE AND NAURU HAVE LOW RECORDS OF DEATH CAUSES IN ALL THE FACTORS, SOME HAD 0 RECORD WHICH MAY BE AS A RESULT OF MISSING VALUES OR NO OSUCH OCCURENCE.
#
# WHILE CHINA, INDIA AND USA HAVE THE GIGHEST RECORD OF DETH CAUSES WHICH ALSO MAY BE AS RESULT OF HIGH POLULATION IN THESE COUNTRIES.

# %% [markdown]
# # OVERVIEW OF ALL TOP COUNTRIES WITH THE HIGHEST DEATH RESULTING FROM HIV

# %%
# HIV CHART

HIV=pd.DataFrame(cd[['Country','Year','HIV_AIDS']].sort_values(['HIV_AIDS'],ascending=False))


fig = px.treemap(HIV.head(300),
                 path = ['Country','Year','HIV_AIDS'],
                 values = 'HIV_AIDS')

title = 'Top Countries Effected By HIV_AIDS'
fig.update_layout(title=title,
                  titlefont={'size': 18,
                             'family': 'Proxima Nova',
                              'color': '#BB3E00',
                            },
                  template='simple_white',
                  paper_bgcolor='#FFF1D7',
                  plot_bgcolor='#FFF1D7',
                  treemapcolorway = ["#BB3E00", "#F7AD45", '#5F8D37', ],
                  height = 1000,
                  width = 800,
                  margin=dict(t=130 ,))
fig.show()
# Out:
# <div>                            <div id="2a0f70bc-a3ed-4350-984b-bf9c357e6f62" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a0f70bc-a3ed-4350-984b-bf9c357e6f62")) {                    Plotly.newPlot(                        "2a0f70bc-a3ed-4350-984b-bf9c357e6f62",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>HIV_AIDS=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Cameroon/2015/34326","Malawi/2011/34354","Cameroon/2012/34372","Tanzania/2017/34451","Zambia/1994/34628","Cameroon/2003/34664","Cameroon/2011/34764","Cameroon/2010/34777","Cote d'Ivoire/2010/34883","Democratic Republic of Congo/2010/34894","Thailand/2003/34901","Cameroon/2013/34931","Cameroo
# ...

# %% [markdown]
# FROM THE CHART ABOVE, SOUTH AFRICA,KENYA, TANZANIA,UGANDA, ZIMBABWE,INDIA, NIGERIA, ETHOPIA, MALAWI,ZAMBIA,MOZAMBIUE, COTE DIVORIE,CAMERON,CONGO RECORDED HIGH DEATH FROM HIV
